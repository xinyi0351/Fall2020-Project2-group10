# %%
import pandas as pd
import numpy as np
from datetime import timedelta

# %%
# Reading in csv files
data090120 = pd.read_csv("../data/09-01-2020.csv") # 3165 rows × 900 columns

# Extracting subset based on states
states = ['Massachusetts', 'New York', 'Pennsylvania', 'Connecticut', 'Virginia', 'Washington DC', 'New Jersey', 
'Delaware', 'Rhode Island', 'Maryland', 'West Virginia']
week1cleaned = data090120[data090120["Province_State"].isin(states)]

# Sorting data in order of Last_Update, Admin2, Province_State
week1cleaned.sort_values(['Last_Update', 'Admin2', 'Province_State'], ascending=[True, True, True])

# Resetting indices
week1cleaned = week1cleaned.reset_index(drop=True)

# Subtracting 1 day from datetime
week1cleaned['Last_Update'] = week1cleaned['Last_Update'].apply(lambda x: pd.to_datetime(x).date()) - timedelta(days=1)

# Loop for extracting and combining week 1 data
a = "../data/09-"
b = ["02", "03", "04", "05", "06", "07"]
c = "-2020.csv"

for i in range(0, 6):
    data = pd.read_csv(a + b[i] + c) # 3165 rows × 900 columns
    subset = data[data["Province_State"].isin(states)]
    subset.sort_values(['Last_Update', 'Admin2', 'Province_State'], ascending=[True, True, True])
    subset = subset.reset_index(drop=True)
    subset['Last_Update'] = subset['Last_Update'].apply(lambda x: pd.to_datetime(x).date()) - timedelta(days=1)
    week1cleaned = pd.concat([week1cleaned,subset])

# Resetting indices
week1cleaned = week1cleaned.reset_index(drop=True)

week1cleaned

# Saving subset as .csv file
#week1cleaned.to_csv (r'../output/week1cleaned.csv', index = False, header=True)
# Out:
#          FIPS      Admin2 Province_State Country_Region Last_Update  \
# 0      9001.0   Fairfield    Connecticut             US  2020-09-01
# 1      9003.0    Hartford    Connecticut             US  2020-09-01
# 2      9005.0  Litchfield    Connecticut             US  2020-09-01
# 3      9007.0   Middlesex    Connecticut             US  2020-09-01
# 4      9009.0   New Haven    Connecticut             US  2020-09-01
# ...       ...         ...            ...            ...         ...
# 2802  54101.0     Webster  West Virginia             US  2020-09-07
# 2803  54103.0      Wetzel  West Virginia             US  2020-09-07
# 2804  54105.0        Wirt  West Virginia             US  2020-09-07
# 2805  54107.0        Wood  West Virginia             US  2020-09-07
# 2806  54109.0     Wyoming  West Virginia             US  2020-09-07
#
#             Lat      Long_  Confirmed  Deaths  Recovered   Active  \
# 0     41.268099 -73.388117      18939    1415          0  17524.0
# 1     41.802830 -72.731039      13529    1425          0  12104.0
# 2     41.793753 -73.245148       1713     138          0   1575.0
# 3     41.459497 -72.537149       1466     192          0   1274.0
# 4     41.408033 -72.936204      13711    1109          0  12602.0
# ...         ...        ...        ...     ...        ...      ...
# 2802  38.493709 -80.420202          7       0          0      7.0
# 2803  39.606577 -80.640165         45       0          0     45.0
# 2804  39.027750 -81.374739          8       0          0      8.0
# 2805  39.209679 -81.516284        324       5          0    319.0
# 2806  37.612327 -81.545111         72       3          0     69.0
#
#                      Combined_Key  Incidence_Rate  Case-Fatality_Ratio
# 0      Fairfield, Connecticut, US     2007.670682             7.471355
# 1       Hartford, Connecticut, US     1517.180281            10.532929
# 2     Litchfield, Connecticut, US      949.909334             8.056042
# 3      Middlesex, Connecticut, US      902.509296            13.096862
# 4      New Haven, Connecticut, US     1604.081628             8.088396
# ...                           ...             ...                  ...
# 2802   Webster, West Virginia, US       86.270643             0.000000
# 2803    Wetzel, West Virginia, US      298.705609             0.000000
# 2804      Wirt, West Virginia, US      137.433431             0.000000
# 2805      Wood, West Virginia, US      387.940324             1.543210
# 2806   Wyoming, West Virginia, US      353.045013             4.166667
#
# [2807 rows x 14 columns]
